# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import QuantileTransformer

from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
import os

# %%
data_folder = 'desktop\CSV_data'

# %%
dataframes = []

# %%
for filename in os.listdir(data_folder):
    if filename.endswith('.csv'):
        file_path = os.path.join(data_folder, filename)
        df = pd.read_csv(file_path)
        # Append label column to the dataframe based on filename
        label = filename.split('_')[0]  # Assuming filenames are in the format: label_fft.csv
        df['label'] = label
        dataframes.append(df)

# %%
ch_data = pd.read_csv(os.path.join(data_folder, 's1chfft.csv'))
a_data = pd.read_csv(os.path.join(data_folder, 's1Afft.csv'))
e_data = pd.read_csv(os.path.join(data_folder, 's1efft.csv'))
u_data = pd.read_csv(os.path.join(data_folder, 's1ufft.csv'))
ya_data= pd.read_csv(os.path.join(data_folder, 's1yafft.csv'))
ka_data= pd.read_csv(os.path.join(data_folder, 's1kafft.csv'))
ch_data = pd.read_csv(os.path.join(data_folder, 's2chfft.csv'))
a_data = pd.read_csv(os.path.join(data_folder, 's2Afft.csv'))
u_data = pd.read_csv(os.path.join(data_folder, 's2ufft.csv'))
e_data = pd.read_csv(os.path.join(data_folder, 's2efft.csv'))
ya_data = pd.read_csv(os.path.join(data_folder, 's2yafft.csv'))
ka_data = pd.read_csv(os.path.join(data_folder, 's2kafft.csv'))
ch_data = pd.read_csv(os.path.join(data_folder, 's3chfft.csv'))
a_data = pd.read_csv(os.path.join(data_folder, 's3Afft.csv'))
u_data = pd.read_csv(os.path.join(data_folder, 's3ufft.csv'))
e_data = pd.read_csv(os.path.join(data_folder, 's3efft.csv'))
ya_data = pd.read_csv(os.path.join(data_folder, 's3yafft.csv'))
ka_data = pd.read_csv(os.path.join(data_folder, 's3kafft.csv'))
ch_data = pd.read_csv(os.path.join(data_folder, 's4chfft.csv'))
a_data = pd.read_csv(os.path.join(data_folder, 's4Afft.csv'))
u_data = pd.read_csv(os.path.join(data_folder, 's4ufft.csv'))
e_data = pd.read_csv(os.path.join(data_folder, 's4efft.csv'))
ya_data= pd.read_csv(os.path.join(data_folder, 's4yafft.csv'))
ka_data= pd.read_csv(os.path.join(data_folder, 's4kafft.csv'))
ch_data = pd.read_csv(os.path.join(data_folder, 's5chfft.csv'))
a_data = pd.read_csv(os.path.join(data_folder, 's5Afft.csv'))
u_data = pd.read_csv(os.path.join(data_folder, 's5ufft.csv'))
e_data = pd.read_csv(os.path.join(data_folder, 's5efft.csv'))
ya_data= pd.read_csv(os.path.join(data_folder, 's5yafft.csv'))
ka_data= pd.read_csv(os.path.join(data_folder, 's5kafft.csv'))
ch_data = pd.read_csv(os.path.join(data_folder, 's6chfft.csv'))
a_data = pd.read_csv(os.path.join(data_folder, 's6Afft.csv'))
u_data = pd.read_csv(os.path.join(data_folder, 's6ufft.csv'))
e_data = pd.read_csv(os.path.join(data_folder, 's6efft.csv'))
ch_data = pd.read_csv(os.path.join(data_folder, 's7chfft.csv'))
a_data = pd.read_csv(os.path.join(data_folder, 's7Afft.csv'))
u_data = pd.read_csv(os.path.join(data_folder, 's7ufft.csv'))
e_data = pd.read_csv(os.path.join(data_folder, 's7efft.csv'))
ya_data= pd.read_csv(os.path.join(data_folder, 's7yafft.csv'))
ka_data= pd.read_csv(os.path.join(data_folder, 's7kafft.csv'))
ch_data = pd.read_csv(os.path.join(data_folder, 's8chfft.csv'))
a_data = pd.read_csv(os.path.join(data_folder, 's8Afft.csv'))
u_data = pd.read_csv(os.path.join(data_folder, 's8ufft.csv'))
e_data = pd.read_csv(os.path.join(data_folder, 's8efft.csv'))
ya_data= pd.read_csv(os.path.join(data_folder, 's8yafft.csv'))
ka_data= pd.read_csv(os.path.join(data_folder, 's8kafft.csv'))
ch_data = pd.read_csv(os.path.join(data_folder, 's9chfft.csv'))
a_data = pd.read_csv(os.path.join(data_folder, 's9Afft.csv'))
u_data = pd.read_csv(os.path.join(data_folder, 's9ufft.csv'))
e_data = pd.read_csv(os.path.join(data_folder, 's9efft.csv'))
ya_data = pd.read_csv(os.path.join(data_folder, 's9yafft.csv'))
ka_data = pd.read_csv(os.path.join(data_folder, 's9kafft.csv'))
ch_data = pd.read_csv(os.path.join(data_folder, 's10chfft.csv'))
a_data = pd.read_csv(os.path.join(data_folder, 's10Afft.csv'))
e_data = pd.read_csv(os.path.join(data_folder, 's10efft.csv'))
u_data = pd.read_csv(os.path.join(data_folder, 's10ufft.csv'))
ya_data= pd.read_csv(os.path.join(data_folder, 's10yafft.csv'))
ka_data= pd.read_csv(os.path.join(data_folder, 's10kafft.csv'))
ch_data = pd.read_csv(os.path.join(data_folder, 's11chfft.csv'))
a_data = pd.read_csv(os.path.join(data_folder, 's11Afft.csv'))
e_data = pd.read_csv(os.path.join(data_folder, 's11efft.csv'))
u_data = pd.read_csv(os.path.join(data_folder, 's11ufft.csv'))
ya_data= pd.read_csv(os.path.join(data_folder, 's11yafft.csv'))
ka_data= pd.read_csv(os.path.join(data_folder, 's11kafft.csv'))
ch_data = pd.read_csv(os.path.join(data_folder, 's12chfft.csv'))
a_data = pd.read_csv(os.path.join(data_folder, 's12Afft.csv'))
e_data = pd.read_csv(os.path.join(data_folder, 's12efft.csv'))
u_data = pd.read_csv(os.path.join(data_folder, 's12ufft.csv'))
ya_data= pd.read_csv(os.path.join(data_folder, 's12yafft.csv'))
ka_data= pd.read_csv(os.path.join(data_folder, 's12kafft.csv'))
ch_data = pd.read_csv(os.path.join(data_folder, 's13chfft.csv'))
a_data = pd.read_csv(os.path.join(data_folder, 's13Afft.csv'))
e_data = pd.read_csv(os.path.join(data_folder, 's13efft.csv'))
u_data = pd.read_csv(os.path.join(data_folder, 's13ufft.csv'))
ya_data= pd.read_csv(os.path.join(data_folder, 's13yafft.csv'))
ka_data= pd.read_csv(os.path.join(data_folder, 's13kafft.csv'))
ch_data = pd.read_csv(os.path.join(data_folder, 's14chfft.csv'))
a_data = pd.read_csv(os.path.join(data_folder, 's14Afft.csv'))
e_data = pd.read_csv(os.path.join(data_folder, 's14efft.csv'))
u_data = pd.read_csv(os.path.join(data_folder, 's14ufft.csv'))
ya_data= pd.read_csv(os.path.join(data_folder, 's14yafft.csv'))
ka_data= pd.read_csv(os.path.join(data_folder, 's14kafft.csv'))
ch_data = pd.read_csv(os.path.join(data_folder,'s1nchfft.csv'))
a_data = pd.read_csv(os.path.join(data_folder, 's1nAfft.csv'))
e_data = pd.read_csv(os.path.join(data_folder, 's1nefft.csv'))
u_data = pd.read_csv(os.path.join(data_folder, 's1nufft.csv'))
ya_data= pd.read_csv(os.path.join(data_folder, 's1nyafft.csv'))
ka_data= pd.read_csv(os.path.join(data_folder, 's1nkafft.csv'))
ch_data = pd.read_csv(os.path.join(data_folder, 's2nchfft.csv'))
a_data = pd.read_csv(os.path.join(data_folder, 's2nAfft.csv'))
e_data = pd.read_csv(os.path.join(data_folder, 's2nefft.csv'))
u_data = pd.read_csv(os.path.join(data_folder, 's2nufft.csv'))
ya_data= pd.read_csv(os.path.join(data_folder, 's2nyafft.csv'))
ka_data= pd.read_csv(os.path.join(data_folder, 's2nkafft.csv'))
ch_data = pd.read_csv(os.path.join(data_folder, 's3nchfft.csv'))
a_data = pd.read_csv(os.path.join(data_folder, 's3nAfft.csv'))
e_data = pd.read_csv(os.path.join(data_folder, 's3nefft.csv'))
u_data = pd.read_csv(os.path.join(data_folder, 's3nufft.csv'))
ya_data= pd.read_csv(os.path.join(data_folder, 's3nyafft.csv'))
ka_data= pd.read_csv(os.path.join(data_folder, 's3nkafft.csv'))
ch_data = pd.read_csv(os.path.join(data_folder, 's4nchfft.csv'))
a_data = pd.read_csv(os.path.join(data_folder, 's4nAfft.csv'))
e_data = pd.read_csv(os.path.join(data_folder, 's4nefft.csv'))
u_data = pd.read_csv(os.path.join(data_folder, 's4nufft.csv'))
ya_data= pd.read_csv(os.path.join(data_folder, 's4nyafft.csv'))
ka_data= pd.read_csv(os.path.join(data_folder, 's4nkafft.csv'))
ch_data = pd.read_csv(os.path.join(data_folder, 's5nchfft.csv'))
a_data = pd.read_csv(os.path.join(data_folder, 's5nAfft.csv'))
e_data = pd.read_csv(os.path.join(data_folder, 's5nefft.csv'))
u_data = pd.read_csv(os.path.join(data_folder, 's5nufft.csv'))
ya_data= pd.read_csv(os.path.join(data_folder, 's5nyafft.csv'))
ka_data= pd.read_csv(os.path.join(data_folder, 's5nkafft.csv'))
ch_data = pd.read_csv(os.path.join(data_folder, 's6nchfft.csv'))
a_data = pd.read_csv(os.path.join(data_folder, 's6nAfft.csv'))
e_data = pd.read_csv(os.path.join(data_folder, 's6nefft.csv'))
u_data = pd.read_csv(os.path.join(data_folder, 's6nufft.csv'))
ya_data= pd.read_csv(os.path.join(data_folder, 's6nyafft.csv'))
ka_data= pd.read_csv(os.path.join(data_folder, 's6nkafft.csv'))
ch_data = pd.read_csv(os.path.join(data_folder, 's7nchfft.csv'))
a_data = pd.read_csv(os.path.join(data_folder, 's7nAfft.csv'))
e_data = pd.read_csv(os.path.join(data_folder, 's7nefft.csv'))
u_data = pd.read_csv(os.path.join(data_folder, 's7nufft.csv'))
ya_data= pd.read_csv(os.path.join(data_folder, 's7nyafft.csv'))
ka_data= pd.read_csv(os.path.join(data_folder, 's7nkafft.csv'))

# %%
ch_data['label'] = 'ch'
a_data['label'] = 'a'
u_data['label'] = 'u'
e_data['label'] = 'e'
ka_data['label'] = 'ka'
ya_data['label'] = 'ya'

# %%
all_data = pd.concat([ch_data, a_data, u_data, e_data, ka_data, ya_data], ignore_index=True)

# %%
X = all_data.drop('label', axis=1)
y = all_data['label']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=70)

# %%
#sc = StandardScaler()
sc = QuantileTransformer(random_state=50)
X_train_scaled = sc.fit_transform(X_train)
X_test_scaled = sc.transform(X_test)

# %%
svm_classifier = SVC(kernel='rbf', random_state=70)
svm_classifier.fit(X_train_scaled, y_train)
# Out:
# SVC(random_state=70)

# %%
y_pred = svm_classifier.predict(X_test_scaled)

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.2731512325116589
